# %% [markdown]
# <a href="https://colab.research.google.com/github/narendra974/Pytorch_Bootcamp_ZTM/blob/main/03_NNClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Neural Network Classification with PyTorch
#
# * what is a classification Problem
#
#   * "Is the email Spam or not Spam" -> Binary Classification
#
# * Is this photo of Sushu, Steak or Pizza
#
#   * Multiclass Classification, more than one
#
# * Deep Learning Page in the Wiki
#
#   * it is Maching Learning or Neural Networks, so multi lable for each sample called MutliLabel Classfication

# %% [markdown]
# ### What we are going to Cover
#   * Architecture of a neural network classification.
#   * input and output shapes of a classificaiton model
#   * Creating custom data
#   * steps in modeling
#     * loss function, optimizer, trainign loop, testing loop
#   * saving and Loading models
#   * Harnessing the power of non-lineraty
#   * Different classification evaluation metrics.

# %% [markdown]
# ### Hperparameters
#
# * Input Layer Shape
# * Hidden Layers
# * Neurons Per Hidden Layer
# * Activation of Hidden Layer (Usually ReLu)
# * Outpur Layer Shaper
# * Output Layer Activation Sigmoid for Binary and Softmax for Mutliclas.
# * Loss Function Binary Cross entropy for Binary Classification and Softmax for Multiclass Classification
# * Optimizer

# %%
# Making a Toy Classification Dataset

import sklearn
from sklearn.datasets import make_circles

# %%
# Make 1000 samples
n_samples = 1000

# Create Circles
X, y = make_circles(n_samples, noise=0.03, random_state=42)
len(X), len(y)
# Out:
# (1000, 1000)

# %%
print(f"First 5 samples of X: \n{X[:5]}")
print(f"First 5 samples of y: \n{y[:5]}")
# Out:
# First 5 samples of X:
# [[ 0.75424625  0.23148074]
#  [-0.75615888  0.15325888]
#  [-0.81539193  0.17328203]
#  [-0.39373073  0.69288277]
#  [ 0.44220765 -0.89672343]]
# First 5 samples of y:
# [1 1 1 1 0]

# %%
# Make DataFrame of circle Data.
import pandas as pd

circles = pd.DataFrame({"X0": X[:, 0], "X1": X[:, 1] })
