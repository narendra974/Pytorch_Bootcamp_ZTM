# %% [markdown]
# <a href="https://colab.research.google.com/github/narendra974/Pytorch_Bootcamp_ZTM/blob/main/Pytorch_Workflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Pytorch Workflow
# * Ground Truth Notebook - https://github.com/mrdbourke/pytorch-deep-learning/blob/main/video_notebooks/01_pytorch_workflow_video.ipynb
# * Book Verison of Note book https://www.learnpytorch.io/01_pytorch_workflow/
# * Ask a Question - https://github.com/mrdbourke/pytorch-deep-learning/discussions
